# %% [markdown]
# git使用教程
#
# #1.clone
# git clone ...url...
#
# #2.workspace to index
# git add ...filename..
#
# #3.index to local(.git)
# git commit -m ...mark...
#
# #4.local to github
# git push origin main
